# %%
import os
from PIL import Image, ImageOps
import sys

print(os.getcwd())
os.chdir('/mnt/c/Users/mateo/OneDrive/Desktop/Projects/_Birdsong/CatDogOrNeither_v2/')

sys.path.append('/mnt/c/Users/mateo/OneDrive/Desktop/Projects/_Birdsong/CatDogOrNeither_v2/backend/app/src')
from utils.preprocess import preprocess_single_image, preprocess_all_images
# Out:
# /mnt/c/Users/mateo/OneDrive/Desktop/Projects/_Birdsong/CatDogOrNeither_v2/backend/app/data/raw

# %%
print(os.getcwd())
# Out:
# /mnt/c/Users/mateo/OneDrive/Desktop/Projects/_Birdsong/CatDogOrNeither_v2

# %%
os.chdir('/mnt/c/Users/mateo/OneDrive/Desktop/Projects/_Birdsong/CatDogOrNeither_v2/backend/app/data/raw')

# %%
print(os.listdir('./cat'))
# Out:
# ['cat.0.jpg', 'cat.0.xml', 'cat.1.jpg', 'cat.1.xml', 'cat.10.jpg', 'cat.10.xml', 'cat.11.jpg', 'cat.11.xml', 'cat.12.jpg', 'cat.12.xml', 'cat.13.jpg', 'cat.13.xml', 'cat.14.jpg', 'cat.14.xml', 'cat.15.jpg', 'cat.15.xml', 'cat.16.jpg', 'cat.16.xml', 'cat.17.jpg', 'cat.17.xml', 'cat.18.jpg', 'cat.18.xml', 'cat.19.jpg', 'cat.19.xml', 'cat.2.jpg', 'cat.2.xml', 'cat.20.jpg', 'cat.20.xml', 'cat.21.jpg', 'cat.21.xml', 'cat.22.jpg', 'cat.22.xml', 'cat.23.jpg', 'cat.23.xml', 'cat.24.jpg', 'cat.24.xml', 'cat.25.jpg', 'cat.25.xml', 'cat.26.jpg', 'cat.26.xml', 'cat.27.jpg', 'cat.27.xml', 'cat.28.jpg', 'cat.28.xml', 'cat.29.jpg', 'cat.29.xml', 'cat.3.jpg', 'cat.3.xml', 'cat.30.jpg', 'cat.30.xml', 'cat.31.jpg', 'cat.31.xml', 'cat.32.jpg', 'cat.32.xml', 'cat.33.jpg', 'cat.33.xml', 'cat.34.jpg', 'cat.34.xml', 'cat.35.jpg', 'cat.35.xml', 'cat.3500.jpg', 'cat.3500.xml', 'cat.3501.jpg', 'cat.3501.xml', 'cat.3502.jpg', 'cat.3502.xml', 'cat.3503.jpg', 'cat.3503.xml', 'cat.3504.jpg', 'cat.3504.xml', 'cat.
# ...

# %%
img = Image.open('./cat/cat.3500.jpg')

# %%
print(img.size)
img.show()
# Out:
# (402, 333)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=402x333>

# %%
target_size = (500, 500)

# %%
warped_img = img.resize(target_size, Image.Resampling.LANCZOS)


padded_img = ImageOps.pad(img, target_size,method = Image.Resampling.LANCZOS, color = (0,0,0))
padded_img.save("../Temp/imgPadded.jpg")

# %%
Image.open("../Temp/imgPadded.jpg")

print(padded_img.size)
# Out:
# (500, 500)

# %%
Image.open('../Temp/imgPadded.jpg')
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x500>

# %%
print(os.getcwd())
# Out:
# /mnt/c/Users/mateo/OneDrive/Desktop/Projects/_Birdsong/CatDogOrNeither_v2/backend/app/data/raw

# %%
#TESTING IMAGE PREPROCESS FUNCTION

input_image_path = "./backend/app/data/raw/dog/dog.109.jpg"


#preprocess the image

processed_image_path = preprocess_single_image(input_image_path)
# Out:
# Error preprocessing image ./backend/app/data/raw/dog/dog.109.jpg: [Errno 2] No such file or directory: '/mnt/c/Users/mateo/OneDrive/Desktop/Projects/_Birdsong/CatDogOrNeither_v2/backend/app/data/raw/backend/app/data/raw/dog/dog.109.jpg'

# %%
raw_dir = "./data/raw"


preprocess_all_images(raw_dir)
# Out:
# processed {processed_counter} files successfully.
# skipped {skipped_counter} files that were already processed.
# encountered errors processing {error_counter} images
